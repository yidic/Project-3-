# %%
import pandas as pd

# %%
songlist = pd.read_csv('song.csv',index_col=0)

# %%
songlist
# Out:
#                                 Song                                 Singer  \
# 0                               Mood           24kGoldn Featuring iann dior
# 1                                WAP  Cardi B Featuring Megan Thee Stallion
# 2                Laugh Now Cry Later               Drake Featuring Lil Durk
# 3                    Blinding Lights                             The Weeknd
# 4   Savage Love (Laxed - Siren Beat)               Jawsh 685 x Jason Derulo
# ..                               ...                                    ...
# 95                          Caramelo          Ozuna x Karol G x Myke Towers
# 96                            Pardon                T.I. Featuring Lil Baby
# 97                      One Too Many             Keith Urban Duet With P!nk
# 98                 Dollaz On My Head             Gunna Featuring Young Thug
# 99                   Champagne Night                                 Lady A
#
#     Rank
# 0      1
# 1      2
# 2      3
# 3      4
# ...

# %%
songnames={}

songnames=songlist['Song']

singernames=songlist['Singer']

song_singer = zip(songnames, singernames)

songsinger = list(song_singer)

# %%
list(songnames)
# Out:
# ['Mood',
#  'WAP',
#  'Laugh Now Cry Later',
#  'Blinding Lights',
#  'Savage Love (Laxed - Siren Beat)',
#  'I Hope',
#  'Dynamite',
#  'Rockstar',
#  'Holy',
#  'Lemonade',
#  'Watermelon Sugar',
#  'Before You Go',
#  'For The Night',
#  'Lonely',
#  'Go Crazy',
#  'Got What I Got',
#  'One Of Them Girls',
#  'Whats Poppin',
#  'Circles',
#  'Be Like That',
#  'Dreams',
#  'Come & Go',
#  'Said Sum',
#  'Kings & Queens',
#  'What You Know Bout Love',
#  'Bang!',
#  'ily',
#  'More Than My Hometown',
#  'Some Girls',
#  'Wonder',
#  'Adore You',
#  'The Woo',
#  'Roses',
#  'Break My Heart',
#  'Whole Lotta Choppas',
#  "Don't Start Now",
#  'One Beer',
#  'Rags2Riches',
#  'Franchise',
#  'Mood Swings',
#  'Love You Like I Used To',
#  'Mr. Right Now',
#  'I Should Probably Go To Bed',
#  'Pretty Heart',
#  "Lovin' On You",
#  'Popstar',
#  'Levitating',
#  'Midnight Sky',
#  'Happy Anywhere',
#  'Runnin',
#  '24',
#  "You're Mines Still",
#  'Tap In',
#  "My Ex's Best Friend",
# ...

# %%
songsinger
# Out:
# [('Mood', '24kGoldn Featuring iann dior'),
#  ('WAP', 'Cardi B Featuring Megan Thee Stallion'),
#  ('Laugh Now Cry Later', 'Drake Featuring Lil Durk'),
#  ('Blinding Lights', 'The Weeknd'),
#  ('Savage Love (Laxed - Siren Beat)', 'Jawsh 685 x Jason Derulo'),
#  ('I Hope', 'Gabby Barrett Featuring Charlie Puth'),
#  ('Dynamite', 'BTS'),
#  ('Rockstar', 'DaBaby Featuring Roddy Ricch'),
#  ('Holy', 'Justin Bieber Featuring Chance The Rapper'),
#  ('Lemonade', 'Internet Money & Gunna Featuring Don Toliver & NAV'),
#  ('Watermelon Sugar', 'Harry Styles'),
#  ('Before You Go', 'Lewis Capaldi'),
#  ('For The Night', 'Pop Smoke Featuring Lil Baby & DaBaby'),
#  ('Lonely', 'Justin Bieber & benny blanco'),
#  ('Go Crazy', 'Chris Brown & Young Thug'),
#  ('Got What I Got', 'Jason Aldean'),
#  ('One Of Them Girls', 'Lee Brice'),
#  ('Whats Poppin', 'Jack Harlow Featuring DaBaby, Tory Lanez & Lil Wayne'),
#  ('Circles', 'Post Malone'),
#  ('Be Like That', 'Kane Brown With Swae Lee & Khalid'),
# ...

# %%
#songname = input("What's your favourite song?")


#def intro():
    #global name
    #name= name.upper()
    #name= name.lower()
   


# i check user song name if  in the list, then we can recommend another hot song  
#if songname in list(songnames):
    #import random
    #choice = random.choice(songnames)
    #print("Maybe you will like :" , choice)
  
       
    
#else:
    #print("sorry this is not hot song")
        
    
        #import random
        #choice = random.choice(songnames)
        #print("sorry this is not hot song, we recommend:" , choice)

# %%
name = input("Hot song you like ")


import random
choice = random.choice(songnames)

if name in list(songnames):
    print("This is hot song,maybe you will like :" , choice)
    
    answer = input("Do you like this song?")
    if answer == "yes":
        print("We are glad to hear")
    
    elif answer == "no":
        print("Sorry, how about this one :", choice)
else:
    print("This is not hot song,we recommend hot song:" , choice)
    
    answer = input("Do you like this song?")
    if answer == "yes":
        print("We are glad to hear")
    
    elif answer == "no":
        choice = random.choice(songnames)
        print("Sorry, how about this one :", choice)
# Out:
# Hot song you like akuhds
# This is not hot song,we recommend hot song: Savage Love (Laxed - Siren Beat)
# Do you like this song?no
# Sorry, how about this one : Hawai

# %%
# 1.spotify playlist 2.get artists 3.list artists 4. get album 
# 5. loop song list (uri, name , audio fearture)
